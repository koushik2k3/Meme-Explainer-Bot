# %%
import openai

# %%
openai.api_key='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'

# %%
model_engine = 'text-davinci-003'

# %%
prompt='explain this meme. meme template: third world problems. text: just used my last pandora skip for the hour next song is even worse'

# %%
completion = openai.Completion.create(
    engine=model_engine,
    prompt=prompt,
    n=1
)

# %%
print(completion.choices[0].text)
# Out:
# This meme is poking fun at the fact that mundane, first world "

# %%
def generate_meme_explanation(template, text):
    # create a prompt using the meme template and text
    prompt = f"Explain the meme with the {template} template that says: {text}"
    
    # generate a response using OpenAI's Completion API
    response = openai.Completion.create(
      engine="text-davinci-003",
      prompt=prompt,
      temperature=0,
      max_tokens=1000,
      n=1,
      stop=None,
    )

    # extract the generated explanation from the API response
    explanation = response.choices[0].text.strip()

    # return the generated explanation
    return explanation

# %%
template = 'pointing_spiderman'
text = 'capital i lower case L  '

# %%
output=generate_meme_explanation(template, text)

# %%
print(output)
# Out:
# This meme is referencing the popular internet meme of Spiderman pointing at someone. In this case, the meme is suggesting that the person being pointed at is a capital "I" and a lowercase "l", which is a common way of representing the word "I'll" (I will). The meme is implying that the person being pointed at is making a promise or commitment to do something.

# %%
import pytesseract
from PIL import Image

def extract_text(image_path):
    # Open the image file using PIL
    with Image.open(image_path) as img:
        # Use pytesseract to extract text from the image
        text = pytesseract.image_to_string(img)
    # Remove escape characters from the extracted text
    text = text.replace('\n', ' ').replace('\r', '')
    return text

# %%
extract_text('./static/images/img6.jpg')
# Out:
# 'BW |. reritis  ‘imafiip.com  UGHT, MODE USERS NY '

# %%
import pandas as pd

# %%
pd.read_csv('./memes_dataset1.csv')['Class'].unique()
# Out:
# array(['distracted_boyfriend', 'this_is_fine', 'mocking_spongebob',
#        'first_world_problems', 'arthur_fist', 'surprised_pikachu',
#        'pointing_spiderman'], dtype=object)
