# %% [markdown]
# # 1. Import Dependencies

# %%
# !pip install opencv-python

# %%
# Import opencv
import cv2 

# Import uuid
import uuid

# Import Operating System
import os

# Import time
import time

# %% [markdown]
# # 2. Image Labelling

# %%
# !pip install --upgrade pyqt5 lxml

# %%
LABELIMG_PATH = os.path.join('Tensorflow', 'labelimg')

# %%
if not os.path.exists(LABELIMG_PATH):
    # !mkdir {LABELIMG_PATH}
    # !git clone https://github.com/tzutalin/labelImg {LABELIMG_PATH}

# %%
labels = ['Hand']
number_imgs = 5

# %%
IMAGES_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'train')

# %%
if not os.path.exists(IMAGES_PATH):
    if os.name == 'posix':
        # !mkdir -p {IMAGES_PATH}
    if os.name == 'nt':
         # !mkdir {IMAGES_PATH}
for label in labels:
    path = os.path.join(IMAGES_PATH, label)
    if not os.path.exists(path):
        # !mkdir {path}

# %%
for label in labels:
    cap = cv2.VideoCapture(0)
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    for imgnum in range(number_imgs):
        print('Collecting image {}'.format(imgnum))
        ret, frame = cap.read()
        imgname = os.path.join(IMAGES_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
        cv2.imwrite(imgname, frame)
        cv2.imshow('frame', frame)
        time.sleep(2)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 3. Resize the images.

# %%
from PIL import Image
import os

# Set the input and output directories
input_dir = './Tensorflow/workspace/images/train_new'
output_dir = './Tensorflow/workspace/images/train_new'

# Loop through all the files in the input directory
for filename in os.listdir(input_dir):
    # Open the image file
    with Image.open(os.path.join(input_dir, filename)) as img:
        # Resize the image to 640x480
        resized_img = img.resize((640, 480))
        # Save the resized image to the output directory
        resized_img.save(os.path.join(output_dir, filename))

# %%
LABELIMG_PATH = os.path.join('Tensorflow', 'labelimg')
# !cd {LABELIMG_PATH} && pyrcc5 -o libs/resources.py resources.qrc
# !cd {LABELIMG_PATH} && python labelImg.py
# Out:
# Image:C:\Users\crkpn\Documents\Programs\barani\TFODCourse\Meme Explainer Bot\Tensorflow\workspace\images\train_new\arthur fist - Copy (2).jpg -> Annotation:C:/Users/crkpn/Documents/Programs/barani/TFODCourse/Meme Explainer Bot/Tensorflow/workspace/images/train_new\arthur fist - Copy (2).xml
# Image:C:\Users\crkpn\Documents\Programs\barani\TFODCourse\Meme Explainer Bot\Tensorflow\workspace\images\train_new\arthur fist - Copy (3).jpg -> Annotation:C:/Users/crkpn/Documents/Programs/barani/TFODCourse/Meme Explainer Bot/Tensorflow/workspace/images/train_new\arthur fist - Copy (3).xml
# Image:C:\Users\crkpn\Documents\Programs\barani\TFODCourse\Meme Explainer Bot\Tensorflow\workspace\images\train_new\arthur fist - Copy (4).jpg -> Annotation:C:/Users/crkpn/Documents/Programs/barani/TFODCourse/Meme Explainer Bot/Tensorflow/workspace/images/train_new\arthur fist - Copy (4).xml
# ...

# %%
# !cd {LABELIMG_PATH} && pyrcc5 -o libs/resources.py resources.qrc

# %%
# !cd {LABELIMG_PATH} && python labelImg.py
# Out:
# Cancel creation.
# Cancel creation.

# %% [markdown]
# # 4. Move them into a Training and Testing Partition
